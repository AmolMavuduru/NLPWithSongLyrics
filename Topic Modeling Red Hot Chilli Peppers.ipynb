# %% [markdown]
# # Topic Modeling with Red Hot Chilli Peppers Lyrics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
rhcp_songs = pd.ExcelFile('RHCP_by_the_way_Im_with_you.xlsx')
im_with_you = pd.read_excel(rhcp_songs, 'Im With You')
by_the_way = pd.read_excel(rhcp_songs, 'By The Way')
the_getaway = pd.read_excel('RHCP Lyrics - The Getaway.xlsx')
stadium_arcadium = pd.read_excel('stadiumArcadium.xlsx')

# %%
im_with_you
# Out:
#            Album                                Song  \
# 0   I'm With You                   Monarchy of Roses
# 1   I'm With You                    Factory of Faith
# 2   I'm With You                Brendan's Death Song
# 3   I'm With You                             Ethiopa
# 4   I'm With You                  Annie Wants A Baby
# 5   I'm With You                         Look Around
# 6   I'm With You  The Adventures of Raindance Maggie
# 7   I'm With You                  Did I Let You Know
# 8   I'm With You                      Goodbye Hooray
# 9   I'm With You             Happiness Loves Company
# 10  I'm With You                      Police Station
# 11  I'm With You                    Even You Brutus?
# 12  I'm With You               Meet Me At The Corner
# 13  I'm With You                 Dance, Dance, Dance
#
#                                                Lyrics
# 0   The crimson tide is flowing through your finge...
# 1   All my life I was swinging for the fence,\nI w...
# ...

# %%
by_the_way
# Out:
#          Album                        Song  \
# 0   By The Way                  By The Way
# 1   By The Way        Universally Speaking
# 2   By The Way           This Is The Place
# 3   By The Way                       Dosed
# 4   By The Way             Don't Forget Me
# 5   By The Way           This Zephyr Place
# 6   By The Way                  Can't Stop
# 7   By The Way         I Could Die For You
# 8   By The Way                    Midnight
# 9   By The Way  Throw Away Your Television
# 10  By The Way                      Cabron
# 11  By The Way                        Tear
# 12  By The Way                  On Mercury
# 13  By The Way                 Minor Thing
# 14  By The Way                   Warm Tape
# 15  By The Way                Venice Queen
# 16  By The Way                Bicycle Song
# 17  By The Way                     Runaway
#
#                                                Lyrics
# 0   Standing in line\nTo see the show tonight\nAnd...
# ...

# %%
the_getaway
# Out:
#     Album Title           Song Title  \
# 0   The Getaway          The Getaway
# 1   The Getaway     Dark Necessities
# 2   The Getaway          We turn red
# 3   The Getaway     The Longest Wave
# 4   The Getaway       Goodbye Angels
# 5   The Getaway            Sick Love
# 6   The Getaway             Go Robot
# 7   The Getaway  Feasting on flowers
# 8   The Getaway              Detroit
# 9   The Getaway  This is ticonderoga
# 10  The Getaway               Encore
# 11  The Getaway           The hunter
# 12  The Getaway  Dreams of a samurai
#
#                                                Lyrics
# 0   That's right you're right\nWe will do our thin...
# 1   Coming on to the light of day\nWe got many moo...
# 2   We got large and we got small,\nWe got a swimm...
# 3   Throw me all around\nLike a boomerang sky\nWha...
# 4   Suicide a month before I met you\nDeep regrets...
# 5   Say goodbye to Oz and everything you own\nCali...
# 6   I called the teacher cause I wanted to confess...
# ...

# %%
stadium_arcadium
# Out:
#                Album                    Song  \
# 0   Stadium Arcadium         Dani California
# 1   Stadium Arcadium                    Snow
# 2   Stadium Arcadium                 Charlie
# 3   Stadium Arcadium        Stadium Arcadium
# 4   Stadium Arcadium            Hump De Bump
# 5   Stadium Arcadium           She's Only 18
# 6   Stadium Arcadium            Slow Cheetah
# 7   Stadium Arcadium              Torture Me
# 8   Stadium Arcadium           Strip My Mind
# 9   Stadium Arcadium  Especially in Michigan
# 10  Stadium Arcadium                Warlocks
# 11  Stadium Arcadium              C'mon Girl
#
#                                                Lyrics
# 0   "Getting born in the state of Mississippi\nPap...
# 1   "fCome to decide that the things that I tried\...
# 2   "All aboard, stitch in time\nGet yours, got mi...
# 3   "\nBells around Saint Petersburg\nWhen I saw y...
# 4   "Forty detectives this week\nForty detectives ...
# ...
