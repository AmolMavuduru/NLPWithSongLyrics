# %% [markdown]
# # Topic Modeling with Red Hot Chilli Peppers Lyrics

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Reading in RHCP Song Data

# %%
rhcp_song_data = pd.read_excel('rhcp_songs.xlsx')
rhcp_song_data
# Out:
#                Album                                Song  \
# 0       I'm With You                   Monarchy of Roses
# 1       I'm With You                    Factory of Faith
# 2       I'm With You                Brendan's Death Song
# 3       I'm With You                             Ethiopa
# 4       I'm With You                  Annie Wants A Baby
# 5       I'm With You                         Look Around
# 6       I'm With You  The Adventures of Raindance Maggie
# 7       I'm With You                  Did I Let You Know
# 8       I'm With You                      Goodbye Hooray
# 9       I'm With You             Happiness Loves Company
# 10      I'm With You                      Police Station
# 11      I'm With You                    Even You Brutus?
# 12      I'm With You               Meet Me At The Corner
# 13      I'm With You                 Dance, Dance, Dance
# 14        By The Way                          By The Way
# 15        By The Way                Universally Speaking
# 16        By The Way                   This Is The Place
# 17        By The Way                               Dosed
# 18        By The Way                     Don't Forget Me
# 19        By The Way                   This Zephyr Place
# 20        By The Way                          Can't Stop
# 21        By The Way                 I Could Die For You
# 22        By The Way                            Midnight
# 23        By The Way          Throw Away Your Television
# 24        By The Way                              Cabron
# 25        By The Way                                Tear
# 26        By The Way                          On Mercury
# 27        By The Way                         Minor Thing
# 28        By The Way                           Warm Tape
# 29        By The Way                        Venice Queen
# ..               ...                                 ...
# 41       The Getaway                 This is ticonderoga
# 42       The Getaway                              Encore
# 43       The Getaway                          The hunter
# 44       The Getaway                 Dreams of a samurai
# 45  Stadium Arcadium                     Dani California
# 46  Stadium Arcadium                                Snow
# 47  Stadium Arcadium                             Charlie
# 48  Stadium Arcadium                    Stadium Arcadium
# 49  Stadium Arcadium                        Hump De Bump
# 50  Stadium Arcadium                       She's Only 18
# 51  Stadium Arcadium                        Slow Cheetah
# 52  Stadium Arcadium                          Torture Me
# 53  Stadium Arcadium                       Strip My Mind
# 54  Stadium Arcadium              Especially in Michigan
# 55  Stadium Arcadium                            Warlocks
# 56  Stadium Arcadium                          C'mon Girl
# 57   Californication                          Get On Top
# 58   Californication                All Around The World
# 59   Californication                         Scar Tissue
# 60   Californication                           Otherside
# 61   Californication                     Californication
# 62   Californication                              Easily
# 63   Californication                           Porcelain
# 64   Californication                         Emit Remmus
# 65   Californication                   This Velvet Glove
# 66   Californication                              Savior
# 67   Californication                        Purple Stain
# 68   Californication                       Road Trippin'
# 69   Californication                           Fat Dance
# 70   Californication                       Right on time
#
#                                                Lyrics
# 0   The crimson tide is flowing through your finge...
# 1   All my life I was swinging for the fence,\nI w...
# 2   If I die before I get it done\nWill you decide...
# 3   We're rolling everybody, it starts with bass"\...
# 4   Lucy Rebar, she's a friend of mine\nLater she'...
# 5   Stiff club, it's my nature,\nCustom love is th...
# 6   Lipstick junkie\nDebunked the all in one\nShe ...
# 7   m comin' for you 'cause I adore you and\nI'd l...
# 8   Wooh, wooh, ha\nJunior paints that old cafe\nH...
# 9   Stop marching 'cause you think you shot to num...
# 10  I saw you at the police station and it breaks ...
# 11  God is good and fate is great\nWhen it feels s...
# 12  Please don't ask me who, \nOr who you think I ...
# 13  You got yours and I got mine\nShe got his and ...
# 14  Standing in line\nTo see the show tonight\nAnd...
# 15  I saw your face\nElegant and tired\nCut up fro...
# 16  This is the place where all \nThe junkies go \...
# 17  I got dosed by you and\nCloser than most to yo...
# 18  I'm an ocean in your bedroom\nMake you feel wa...
# 19  Can I get your hand to write on\nJust a piece ...
# 20  Can't stop, addicted to the shindig\nChop Top,...
# 21  Something inside the cards\nI know is right\nD...
# 22  Things will never be the same\nStill I'm awful...
# 23  Throw away your television\nTime to make this ...
# 24  Cabron \nCabron \nCabron \nCabron\nI see you i...
# 25  This is my time\nThis is my tear\nI can see cl...
# 26  I've got myself\nIn a masochistic hold\nWhy do...
# 27  I change the key from C to D \nYou see to me i...
# 28  Shiver for me girl \nDeliver for me my darling...
# 29  Does it go from east to west \nBody free and a...
# ..                                                ...
# 41  I met a man in a rock and roll band he said wo...
# 42  Listen to the Beatles and the sound of laughin...
# 43  Woke up this morning like I always do\nI still...
# 44  Standing naked in your kitchen\nFeeling free t...
# 45  "Getting born in the state of Mississippi\nPap...
# 46  "fCome to decide that the things that I tried\...
# 47  "All aboard, stitch in time\nGet yours, got mi...
# 48  "\nBells around Saint Petersburg\nWhen I saw y...
# 49  "Forty detectives this week\nForty detectives ...
# 50  She's only eighteen\nDon't like the Rollin' St...
# 51  "Waking up dead inside of my head\nWill never ...
# 52  "Because I'm happy to be sad\nI want it all I ...
# 53  "Oh, yeah yeah\nWow, wow, wow, wow, yeah\nArth...
# 54  "\nLife is my friend \nRake it up to take it i...
# 55  "\nWarlocks in wonderland \nI've gotta megatro...
# 56  "\nEverything inside of me\nIs burning up for ...
# 57  Get on top \nGet on top\nHit me (get on top) c...
# 58  All around the world\nWe could make timerompin...
# 59  Scar tissue that I wish you saw\nSarcastic mis...
# 60  How long, how long will I slide?\nSeparate my ...
# 61  Psychic spies from China try to steal your min...
# 62  Easily let's get carried away\nEasily let's ge...
# 63  Porcelain, are you wasting away in your skin\n...
# 64  The California animal is a bear\nAngeleno but ...
# 65  Close to my skin\nI'm falling in someone who's...
# 66  Dusting off your savior\nWell, you were always...
# 67  To finger paint is not a sin \nI put my middle...
# 68  Road trippin' with my two favorite allies \nFu...
# 69  Do a phfat dance\nDo a phfat dance\nDo a do a ...
# 70  One shot, all I need I've got rhythm when I bl...
#
# [71 rows x 3 columns]

# %%
songs = []
for i in range(71):
    print(rhcp_song_data['Song'].loc[i])
    songs.append(rhcp_song_data['Song'].loc[i])
songs
# Out:
# Monarchy of Roses
# Factory of Faith
# Brendan's Death Song
# Ethiopa
# Annie Wants A Baby
# Look Around
# The Adventures of Raindance Maggie
# Did I Let You Know
# Goodbye Hooray
# Happiness Loves Company
# Police Station
# Even You Brutus?
# Meet Me At The Corner
# Dance, Dance, Dance
# By The Way
# Universally Speaking
# This Is The Place
# Dosed
# Don't Forget Me
# This Zephyr Place
# Can't Stop
# I Could Die For You
# Midnight
# Throw Away Your Television
# Cabron
# Tear
# On Mercury
# Minor Thing
# Warm Tape
# Venice Queen
# Bicycle Song
# Runaway
# The Getaway
# Dark Necessities
# We turn red
# The Longest Wave
# Goodbye Angels
# Sick Love
# Go Robot
# Feasting on flowers
# Detroit
# This is ticonderoga
# Encore
# The hunter
# Dreams of a samurai
# Dani California
# Snow
# Charlie
# Stadium Arcadium
# Hump De Bump
# She's Only 18
# Slow Cheetah
# Torture Me
# Strip My Mind
# Especially in Michigan
# Warlocks
# C'mon Girl
# Get On Top
# All Around The World
# Scar Tissue
# Otherside
# Californication
# Easily
# Porcelain
# Emit Remmus
# This Velvet Glove
# Savior
# Purple Stain
# Road Trippin'
# Fat Dance
# Right on time
# ['Monarchy of Roses',
#  'Factory of Faith',
#  "Brendan's Death Song",
#  'Ethiopa',
#  'Annie Wants A Baby',
#  'Look Around',
#  'The Adventures of Raindance Maggie',
#  'Did I Let You Know',
#  'Goodbye Hooray',
#  'Happiness Loves Company',
#  'Police Station',
#  'Even You Brutus?',
#  'Meet Me At The Corner',
#  'Dance, Dance, Dance',
#  'By The Way',
#  'Universally Speaking',
#  'This Is The Place',
#  'Dosed',
#  "Don't Forget Me",
#  'This Zephyr Place',
#  "Can't Stop",
#  'I Could Die For You',
#  'Midnight',
#  'Throw Away Your Television',
#  'Cabron',
#  'Tear',
#  'On Mercury',
#  'Minor Thing',
#  'Warm Tape',
#  'Venice Queen',
#  'Bicycle Song',
#  'Runaway',
#  'The Getaway',
#  'Dark Necessities',
#  'We turn red',
#  'The Longest Wave',
#  'Goodbye Angels',
#  'Sick Love',
#  'Go Robot',
#  'Feasting on flowers',
#  'Detroit',
#  'This is ticonderoga',
#  'Encore',
#  'The hunter',
#  'Dreams of a samurai',
#  'Dani California',
#  'Snow',
#  'Charlie',
#  'Stadium Arcadium',
#  'Hump De Bump',
#  "She's Only 18",
#  'Slow Cheetah',
#  'Torture Me',
#  'Strip My Mind',
#  'Especially in Michigan',
#  'Warlocks',
#  "C'mon Girl",
#  'Get On Top',
#  'All Around The World',
#  'Scar Tissue',
#  'Otherside',
#  'Californication',
#  'Easily',
#  'Porcelain',
#  'Emit Remmus',
#  'This Velvet Glove',
#  'Savior',
#  'Purple Stain',
#  "Road Trippin'",
#  'Fat Dance',
#  'Right on time']

# %%
line_list = []
songs = []
albums = []
for i in range(len(rhcp_song_data)):
    lines = rhcp_song_data.loc[i, 'Lyrics'].split('\n')
    for line in lines: 
        line_list.append(line)
        songs.append(rhcp_song_data['Song'].loc[i])
        albums.append(rhcp_song_data['Album'].loc[i])
        
rhcp_song_lines = pd.DataFrame({'Album': albums, 'Song': songs, 'Line': line_list})
rhcp_song_lines
# Out:
#                 Album                                               Line  \
# 0        I'm With You  The crimson tide is flowing through your finge...
# 1        I'm With You  The promise of a clean regime are promises we ...
# 2        I'm With You  Do you like it rough I ask and are you up to t...
# 3        I'm With You  The catacombs of bet and bone where cultures c...
# 4        I'm With You                  Several of my best friends wear,
# 5        I'm With You                            The colors of the crown
# 6        I'm With You                     And Mary wants to fill it up,
# 7        I'm With You    And Sherry wants to tear it all back down, girl
# 8        I'm With You                           The savior of your light
# 9        I'm With You                             The monarchy of roses
# 10       I'm With You                      The monarchy of roses tonight
# 11       I'm With You  The cloth between my former queen, her legenda...
# 12       I'm With You  The holy tears that I am in, the lovely cross ...
# 3630      Right on time
# 3631      Right on time
# 3632      Right on time
# 3633      Right on time
# 3634      Right on time
# 3635      Right on time
# 3636      Right on time
# 3637      Right on time
# 3638      Right on time
# 3639      Right on time
# 3640      Right on time
# 3641      Right on time
# 3642      Right on time
# 3643      Right on time
# 3644      Right on time
# 3645      Right on time
# 3646      Right on time
# 3647      Right on time
#
# [3648 rows x 3 columns]

# %% [markdown]
# ## Preprocessing the Raw Text Data

# %%
import re # regex library
def preprocessor(text):
    text = re.sub('<[^>]*>', '', text) # Effectively removes HTML markup tags
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text) # Finds emoticons and punctuation
    text = re.sub('[\W]+', ' ', text.lower()) + ' '.join(emoticons).replace('-', '') # removes uppercase and emoticons
    text = re.sub("[^A-Za-z]", " ", text) # removes non-letter characters (numbers)
    return text

# %%
rhcp_song_lines['Processed Lyrics'] = rhcp_song_lines['Line'].apply(preprocessor)

# %% [markdown]
# ## Running Latent Dirichlet Allocation with a Count Vectorizer
#
# **Latent Dirichlet Allocation** is an unsupervised algorithm for topic modeling that can be used to generate topics from any **corpus**. Here are some basic terms and concepts behind LDA:
# - A **document** is defined as a sequence of words. In this case, a document is just a single email.
# - A **corpus** is a collection of documents, which in this case is a collection of emails.
# - A **topic** is characterized by a particular probability distribution over different words. For example, in the topic of **soccer** certain words such as **free kick** and **offside** are more likely to appear than others.
# - A document contains a **mixture of different topics** with some topics being more relevant or prominent than others.
# - LDA involves using the **Dirichlet distribution** to model the distribution of words among different topics.
#
# The LDA algorithm allows us to not only extract the major topics from a corpus, but also allows us to create a model that can be used to infer which of these topics are most prevalent in any given document, even if it was not present in the original corpus.

# %%
from spacy.lang.en.stop_words import STOP_WORDS
STOP_WORDS = STOP_WORDS.union(set(['girl', 'll', 'don', 'let', 'gon']))

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

num_topics = 5
num_features= 5000

print('Running CountVectorizer...')
tf_vectorizer = CountVectorizer(max_df=0.90, min_df=10, ngram_range=(1,1), max_features=num_features, stop_words=STOP_WORDS)
tf = tf_vectorizer.fit_transform(rhcp_song_lines['Processed Lyrics'])
tf_feature_names = tf_vectorizer.get_feature_names()

print('Running Latent Dirichlet Allocation...')
lda = LatentDirichletAllocation(n_topics=num_topics,
                                max_iter=5, 
                                learning_method='online', 
                                learning_offset=100.,
                                random_state=0).fit(tf)
# Out:
# Running CountVectorizer...
# Running Latent Dirichlet Allocation...

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

num_top_words=10
display_topics(lda, tf_feature_names, num_top_words)
# Out:
# Topic 0:
# right world ayo coming friend mirror light think cabron fine
# Topic 1:
# like want love said look inside know told day sun
# Topic 2:
# oh away life long night dream baby californication feel wanna
# Topic 3:
# know time got come ve tell little mind good sure
# Topic 4:
# dance yeah phfat cause way find hey share need lonely

# %%
lda.perplexity(tf)
# Out:
# 131.7363488835548

# %%
from sklearn.model_selection import train_test_split
X = rhcp_song_lines['Line']
y = rhcp_song_lines['Album']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=100)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
pipeline = Pipeline([('tf', TfidfVectorizer(preprocessor=preprocessor, 
                                            ngram_range=(1,2),
                                            stop_words='english')), 
                    ('mlp', MLPClassifier(hidden_layer_sizes=[1000,1000,1000]))])

# %%
pipeline.fit(X_train, y_train)

# %%
from sklearn.metrics import accuracy_score
pred = pipeline.predict(X_test)
print(accuracy_score(y_test, pred))
# Out:
# 0.5835616438356165

# %% [markdown]
# ## Topic Modeling with LDA2VEC
